# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/PurvaChiniya/age-estimation/blob/master/linear_regression.ipynb)

# %%
import pandas as pd
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
import sklearn
import warnings
warnings.simplefilter(action='ignore',category=FutureWarning)
from sklearn import linear_model 
from sklearn.cross_validation import train_test_split
# %matplotlib inline
xs=[1,2,3,6,4,56,45,67,8,9,0]
ys=[22,4,5,7,7,8,5,6,8,78,9]

plt.scatter(xs,ys,color="green")
plt.ylabel("dependent variable")
plt.xlabel("independent variable")
plt.show()
def slope_intercept(a,b):
     x=np.array(a)
     y=np.array(b)
     m=(((np.mean(x)*np.mean(y))-np.mean(x*y))/((np.mean(x)*np.mean(x))-np.mean(x*x))
     )
     m=round(m,3)
     b=(np.mean(y)-np.mean(x)*m)
     b=round(b,3)
     return m,b
slope_intercept(xs,ys)
m,b=slope_intercept(xs,ys)
reg_line=((m*x)+b for x in xs)
plt.scatter(xs,ys,color="red")
plt.ylabel("dependent variable")
plt.xlabel("independent variable")
plt.title("making a regression line")
plt.plot(xs,reg_line)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/matplotlib/units.py in get_converter(self, x)
#     143                 # get_converter
# --> 144                 if not np.all(xravel.mask):
#     145                     # some elements are not masked
#
# AttributeError: 'numpy.ndarray' object has no attribute 'mask'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-94893c99947d> in <module>()
#      34 plt.xlabel("independent variable")
#      35 plt.title("making a regression line")
# ---> 36 plt.plot(xs,reg_line)
#      37 plt.show()
#      38
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# ...
